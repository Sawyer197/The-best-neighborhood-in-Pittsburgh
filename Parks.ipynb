# %% [markdown]
# This code reads each file's data and ranks the neighborhoods into different categories on the average rate they hold.
# The three neighborhoods for each categories that are ranked number one will each have an average, and the highest average for amount of city parks, low crime rate, and low traffic will be picked as Pittsburgh best neighborhood.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
link = "https://data.wprdc.org/datastore/dump/fa329e3d-89ff-4708-8ddf-81bfedcad11d"
park = pd.read_csv(link)
parkAmount = park['neighborhood'].value_counts().head(10)
parkAmount.plot(kind = 'bar')
plt.title("Top ten best neighborhoods with parks")
plt.xlabel('Neighborhood')
plt.ylabel('Amount of Parks')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
print("Top ten best neighborhoods with parks:")
print("")
print(parkAmount)
# Out:
# Top ten best neighborhoods with parks:
#
# East Liberty                 12
# Central Business District    10
# Beechview                     8
# South Side Slopes             7
# Point Breeze                  7
# Squirrel Hill South           6
# Mount Washington              6
# Sheraden                      6
# Hazelwood                     6
# South Side Flats              6
# Name: neighborhood, dtype: int64
